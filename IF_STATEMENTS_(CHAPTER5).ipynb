# %% [markdown]
# <a href="https://colab.research.google.com/github/Hooriya-Wajid/demo-repo/blob/main/IF_STATEMENTS_(CHAPTER5).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cars=['audi','bmw','subaru','toyota']
for car in cars:
   if car=='bmw':
          print(car.upper())
   else:
          print(car.title())
# Out:
# Audi
# BMW
# Subaru
# Toyota

# %% [markdown]
# #Indentation plays a vital role here, else it gives errors

# %%
#Conditional Tests​

#Ignoring Case When Checking for Equality​

# %%
car='Audi'
car=='audi'
# Out:
# False

# %%
car='Audi'
car.lower()=='audi'
car
# Out:
# 'Audi'

# %% [markdown]
# #But if case doesn’t matter, you can convert the variable’s value to lowercase before doing the comparison​

# %% [markdown]
# Checking for Inequality​

# %%
requested_topping='mushrooms'
if requested_topping!='anchovies':
  print("Hold the anchovies!")
# Out:
# Hold the anchovies!

# %%
#Numerical Comparisons

# %%
age=18
age==18
# Out:
# True

# %%
answer=17
if answer!=42:
  print("That's not the correct answer.Please try again!")
# Out:
# That's not the correct answer.Please try again!

# %% [markdown]
# Checking Multiple Conditions​
#
# (using AND)

# %%
age_0=22
age_1=18

age_0>=21 and age_1>=21
# Out:
# False

# %%
age_0=22
age_1=22

age_0>=21 and age_1>=21
# Out:
# True

# %% [markdown]
# Checking Multiple Conditions​
#
# (using OR)

# %%
age_0,age_1 =22,18

age_0>=21 or age_1>=21
# Out:
# True

# %%
age_0,age_1 =18,18

age_0>=21 or age_1>=21
# Out:
# False

# %% [markdown]
# Checking Whether a Value Is in a List​

# %%
requested_toppings=['mushrooms','onions','pineapple']
'mushrooms' in requested_toppings
# Out:
# True

# %%
'pepperoni'in requested_toppings
# Out:
# False

# %% [markdown]
# Checking Whether a Value Is Not in a List​

# %%
banned_users=['andrew','carolina','david']
user='marie'
if user not in banned_users:
  print(f"{user.title()},you can post a response if you wish.")
# Out:
# Marie,you can post a response if you wish.

# %% [markdown]
# Not Operator​

# %%
number=-5
if not number>0:
  print("The number is not positive.")
# Out:
# The number is not positive.

# %% [markdown]
# Checking if a list is empty​

# %%
my_list=[]
if not my_list:
  print("The list is empty.")
# Out:
# The list is empty.

# %% [markdown]
# Checking if a user is not logged in​

# %%
is_logged_in=False
if not is_logged_in:
  print("User is not logged in. Please log in.")
# Out:
# User is not logged in. Please log in.

# %% [markdown]
# Negating a comparison​

# %%
x=10
if not x==5:
  print("x is not equal to 5.")
# Out:
# x is not equal to 5.

# %% [markdown]
# Negating a Boolean flag​

# %%
task_completed=False
if not task_completed:
  print("The task is not yet completed.")
# Out:
# The task is not yet completed.

# %% [markdown]
# Conditional Tests​

# %%
age=19
if age>=18:
  print("You are old enough to vote!")
  print("Have you registered to vote yet?")
# Out:
# You are old enough to vote!
# Have you registered to vote yet?

# %% [markdown]
# if-else Statements​

# %%
age=17
if age>=18:
  print("You are old enough to vote!")
  print("Have you registered to vote yet?")
else:
  print("Sorry,you are too young to vote.")
  print("Please register to vote as soon as you are 18!")
# Out:
# Sorry,you are too young to vote.
# Please register to vote as soon as you are 18!

# %% [markdown]
# The if-elif-else Chain​

# %%
age=12
if age<4:
  print("Your admission cost is $0.")
elif age<18:
   print("Your admission cost is $25.")
else:
   print("Your admission cost is $40.")
# Out:
# Your admission cost is $25.

# %% [markdown]
# The if-elif-else Chain​

# %%
age=12
if age<4:
  price=0
elif age<18:
  price=25
else:
  price=40
print(f"Your admission cost is ${price}.")
# Out:
# Your admission cost is $25.

# %% [markdown]
# Using Multiple elif Blocks​

# %%
age=12
if age<4:
  price=0
elif age<18:
  price=25
elif age<65:
  price=40
else:
  price=20
print(f"Your admission cost is ${price}.")
# Out:
# Your admission cost is $25.

# %% [markdown]
# Omitting the else Block​

# %%
age=12
if age<4:
  price=0
elif age<18:
  price=25
elif age<65:
  price=40
elif age>=65:
  price=20
print(f"Your admission cost is ${price}.")
# Out:
# Your admission cost is $25.

# %% [markdown]
# Testing Multiple Conditions​

# %%
requested_toppings=['mushrooms','extra cheese']
if 'mushrooms' in requested_toppings:
  print("Adding mushrooms.")
if 'pepperoni'in requested_toppings:
    print("Adding pepperoni.")
if 'extra cheese' in requested_toppings:
  print("Adding extra cheese.")
print("\nfinished making your pizza")
# Out:
# Adding mushrooms.
# Adding extra cheese.
#
# finished making your pizza

# %%
requested_toppings=['mushrooms','extra cheese']
if 'mushrooms' in requested_toppings:
  print("Adding mushrooms.")
elif 'pepperoni'in requested_toppings:
    print("Adding pepperoni.")
else:
  'extra cheese' in requested_toppings
  print("Adding extra cheese.")
# Out:
# Adding mushrooms.

# %% [markdown]
# Using if Statements with Lists​

# %%
requested_toppings=['mushrooms','green peppers','extra cheese']
for requested_topping in requested_toppings:
  print(f"Adding {requested_topping}.")
print("Finished making your pizza!")
# Out:
# Adding mushrooms.
# Adding green peppers.
# Adding extra cheese.
# Finished making your pizza!

# %% [markdown]
# But what if the pizzeria runs out of green peppers? ​

# %%
requested_toppings=['mushrooms','green peppers','extra cheese']
for requested_topping in requested_toppings:
  if requested_topping=='green peppers':
    print("Sorry, we are out of green_peppers right now.")

  else:
       print(f"Adding {requested_topping}.")
print("Finished making your pizza!")
# Out:
# Adding mushrooms.
# Sorry, we are out of green_peppers right now.
# Adding extra cheese.
# Finished making your pizza!

# %% [markdown]
# Checking That a List Is Not Empty​

# %%
requested_toppings=[]
if requested_toppings:
  for requested_topping in requested_toppings:
    print(f"Adding{requested_topping}.")
  print("\nFinished making your pizza!")
else:
  print("Are you sure you want a pizza?")
# Out:
# Are you sure you want a pizza?

# %% [markdown]
# Using Multple Lists

# %%
available_toppings=['mushrooms','olives','green peppers','pepperoni','pineapple','extra cheese']
requested_toppings=['mushrooms','french fries','extra cheese']
for requested_topping in requested_toppings:
  if requested_topping in available_toppings:
    print(f"Adding {requested_topping}.")
  else:
      print(f"Sorry, we dont have a {requested_topping}.")
print("\nFinsihed making your pizza!")
# Out:
# Adding mushrooms.
# Sorry, we dont have a french fries.
# Adding extra cheese.
#
# Finsihed making your pizza!
